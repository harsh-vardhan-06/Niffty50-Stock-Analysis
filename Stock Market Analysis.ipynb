# %% [markdown]
# # Portfolio analysis

# %% [markdown]
# Initial investment =10,00,000
#
# No. of companies = 50
#
# Each company investment amount = 20000

# %% [markdown]
# List of companies niffty fifty companies:-
#
#     MARUTI, RELIANCE, APOLLOHOSP, NTPC, HEROMOTOCO, POWERGRID, M&M, ONGC, COALINDIA, BAJAJ-AUTO, BAJAJFINSV, KOTAKBANK
#     TITAN, EICHERMOT, UPL, HDFC, NESTLEIND, LT, TATAMOTORs, BRITANNIA, BAJFINANCE, HDFCBANK, INDUSINDBK, ASIANPAINT
#     HINDUNILVR, BHARTIARTL, WIPRO, TCS, UlTRACEMCO, ITC, ADANIENT, SBILIFE, HCLTECH, ADANIPORTS, HDFCLIFE, BPCL, INFY
#     CIPLA,DRREDDY, TATACONSUM, AXISBANK, SBIN, JSWSTEEL, ICICIBANK, HINDALCO, DIVISLAB, GRASIM, SUNPHARMA, TATASTEEL, TECHM

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

import warnings
warnings.filterwarnings("ignore")

# %%
list_of_companies=['MARUTI', 'RELIANCE', 'APOLLOHOSP', 'NTPC', 'HEROMOTOCO', 'POWERGRID', 'M&M', 'ONGC', 
                   'COALINDIA', 'BAJAJ-AUTO', 'BAJAJFINSV', 'KOTAKBANK','TITAN', 'EICHERMOT', 'UPL', 'HDFC', 
                   'NESTLEIND', 'LT', 'TATAMOTORs', 'BRITANNIA', 'BAJFINANCE', 'HDFCBANK', 'INDUSINDBK', 'ASIANPAINT', 
                   'HINDUNILVR', 'BHARTIARTL', 'WIPRO', 'TCS', 'UlTRACEMCO', 'ITC', 'ADANIENT', 'SBILIFE', 'HCLTECH', 
                   'ADANIPORTS', 'HDFCLIFE', 'BPCL', 'INFY','CIPLA', 'DRREDDY', 'TATACONSUM', 'AXISBANK', 'SBIN', 'JSWSTEEL', 
                   'ICICIBANK', 'HINDALCO', 'DIVISLAB', 'GRASIM', 'SUNPHARMA', 'TATASTEEL', 'TECHM']

# %% [markdown]
# # Creating a dataset

# %%
df=pd.read_csv("D:\\data set\\niffty50\\MARUTI.NS.csv")
df1=pd.read_csv("D:\\data set\\niffty50\\RELIANCE.NS.csv")
df2=pd.read_csv("D:\\data set\\niffty50\\APOLLOHOSP.NS.csv")
df3=pd.read_csv("D:\\data set\\niffty50\\NTPC.NS.csv")
df4=pd.read_csv("D:\\data set\\niffty50\\HEROMOTOCO.NS.csv")
df5=pd.read_csv("D:\\data set\\niffty50\\POWERGRID.NS.csv")
df6=pd.read_csv("D:\\data set\\niffty50\\M&M.NS.csv")
df7=pd.read_csv("D:\\data set\\niffty50\\ONGC.NS.csv")
df8=pd.read_csv("D:\\data set\\niffty50\\COALINDIA.NS.csv")
df9=pd.read_csv("D:\\data set\\niffty50\\BAJAJ-AUTO.NS.csv")
df10=pd.read_csv("D:\\data set\\niffty50\\BAJAJFINSV.NS.csv")

df11=pd.read_csv("D:\\data set\\niffty50\\KOTAKBANK.NS.csv")
df12=pd.read_csv("D:\\data set\\niffty50\\TITAN.NS.csv")
df13=pd.read_csv("D:\\data set\\niffty50\\EICHERMOT.NS.csv")
df14=pd.read_csv("D:\\data set\\niffty50\\UPL.NS.csv")
df15=pd.read_csv("D:\\data set\\niffty50\\HDFCLIFE.NS.csv")
df16=pd.read_csv("D:\\data set\\niffty50\\NESTLEIND.NS.csv")
df17=pd.read_csv("D:\\data set\\niffty50\\LT.NS.csv")
df18=pd.read_csv("D:\\data set\\niffty50\\TATAMOTORs.NS.csv")
df19=pd.read_csv("D:\\data set\\niffty50\\BRITANNIA.NS.csv")
df20=pd.read_csv("D:\\data set\\niffty50\\BAJFINANCE.NS.csv")

df21=pd.read_csv("D:\\data set\\niffty50\\HDFCBANK.NS.csv")
df22=pd.read_csv("D:\\data set\\niffty50\\INDUSINDBK.NS.csv")
df23=pd.read_csv("D:\\data set\\niffty50\\ASIANPAINT.NS.csv")
df24=pd.read_csv("D:\\data set\\niffty50\\HINDUNILVR.NS.csv")
df25=pd.read_csv("D:\\data set\\niffty50\\BHARTIARTL.NS.csv")
df26=pd.read_csv("D:\\data set\\niffty50\\WIPRO.NS.csv")
df27=pd.read_csv("D:\\data set\\niffty50\\TCS.NS.csv")
df28=pd.read_csv("D:\\data set\\niffty50\\UlTRACEMCO.NS.csv")
df29=pd.read_csv("D:\\data set\\niffty50\\ITC.NS.csv")
df30=pd.read_csv("D:\\data set\\niffty50\\ADANIENT.NS.csv")

df31=pd.read_csv("D:\\data set\\niffty50\\SBILIFE.NS.csv")
df32=pd.read_csv("D:\\data set\\niffty50\\HCLTECH.NS.csv")
df33=pd.read_csv("D:\\data set\\niffty50\\ADANIPORTS.NS.csv")
df34=pd.read_csv("D:\\data set\\niffty50\\HDFCLIFE.NS.csv")
df35=pd.read_csv("D:\\data set\\niffty50\\BPCL.NS.csv")
df36=pd.read_csv("D:\\data set\\niffty50\\INFY.NS.csv")
df37=pd.read_csv("D:\\data set\\niffty50\\CIPLA.NS.csv")
df38=pd.read_csv("D:\\data set\\niffty50\\DRREDDY.NS.csv")
df39=pd.read_csv("D:\\data set\\niffty50\\TATACONSUM.NS.csv")
df40=pd.read_csv("D:\\data set\\niffty50\\AXISBANK.NS.csv")

df41=pd.read_csv("D:\\data set\\niffty50\\SBIN.NS.csv")
df42=pd.read_csv("D:\\data set\\niffty50\\JSWSTEEL.NS.csv")
df43=pd.read_csv("D:\\data set\\niffty50\\ICICIBANK.NS.csv")
df44=pd.read_csv("D:\\data set\\niffty50\\HINDALCO.NS.csv")
df45=pd.read_csv("D:\\data set\\niffty50\\DIVISLAB.NS.csv")
df46=pd.read_csv("D:\\data set\\niffty50\\GRASIM.NS.csv")
df47=pd.read_csv("D:\\data set\\niffty50\\SUNPHARMA.NS.csv")
df48=pd.read_csv("D:\\data set\\niffty50\\TATASTEEL.NS.csv")
df49=pd.read_csv("D:\\data set\\niffty50\\TECHM.NS.csv")

# %%
dataframelist=[df,df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16
               ,df17,df18,df19,df20,df21,df22,df23,df24,df25,df26,df27,df28,df29,df30,df31,df32,df33
               ,df34,df35,df36,df37,df38,df39,df40,df41,df42,df43,df44,df45,df46,df47,df48,df49]

# %%
df
# Out:
#            Date         Open         High          Low        Close  \
# 0    2020-10-01  6838.200195  6909.000000  6775.399902  6796.299805
# 1    2020-10-05  6865.000000  6877.600098  6745.000000  6818.850098
# 2    2020-10-06  6858.000000  6939.799805  6830.000000  6892.399902
# 3    2020-10-07  6920.000000  7070.000000  6865.549805  7046.899902
# 4    2020-10-08  7090.000000  7140.000000  7021.000000  7079.850098
# ..          ...          ...          ...          ...          ...
# 510  2022-10-21  8730.000000  8794.000000  8641.000000  8703.299805
# 511  2022-10-24  8788.799805  8788.799805  8745.849609  8765.450195
# 512  2022-10-25  8820.000000  9017.000000  8797.400391  9005.000000
# 513  2022-10-27  9050.000000  9076.950195  8902.000000  9041.950195
# 514  2022-10-28  9095.000000  9549.950195  9051.000000  9492.549805
#
#        Adj Close   Volume
# 0    6709.069824  1255993
# 1    6731.331055   833476
# 2    6803.936523   756192
# 3    6956.454102  1101957
# ...

# %%
#Data base Creation
data=pd.DataFrame()
data['Date']=df['Date']


#Creating names of columns
name_o=[]
name_c=[]
for n in list_of_companies:
    name_o.append(n+'_o')
    name_c.append(n+'_c')


#creating a dataset with open and close values only
i=0
for col in dataframelist:
    data[name_o[i]]=col['Open']
    data[name_c[i]]=col['Close']
    i+=1

# %%
data
# Out:
#            Date     MARUTI_o     MARUTI_c   RELIANCE_o   RELIANCE_c  \
# 0    2020-10-01  6838.200195  6796.299805  2263.800049  2225.250000
# 1    2020-10-05  6865.000000  6818.850098  2244.000000  2212.199951
# 2    2020-10-06  6858.000000  6892.399902  2225.250000  2210.350098
# 3    2020-10-07  6920.000000  7046.899902  2235.000000  2257.500000
# 4    2020-10-08  7090.000000  7079.850098  2259.000000  2239.250000
# ..          ...          ...          ...          ...          ...
# 510  2022-10-21  8730.000000  8703.299805  2507.699951  2471.600098
# 511  2022-10-24  8788.799805  8765.450195  2460.000000  2479.850098
# 512  2022-10-25  8820.000000  9005.000000  2499.000000  2441.550049
# 513  2022-10-27  9050.000000  9041.950195  2458.000000  2451.149902
# 514  2022-10-28  9095.000000  9492.549805  2465.000000  2526.149902
#
#      APOLLOHOSP_o  APOLLOHOSP_c      NTPC_o      NTPC_c  HEROMOTOCO_o  ...  \
# ...

# %% [markdown]
# #Now Buying the share(Creating the quantity (1000000/50=20000)20000 assigned for every company)
#
# name_o:- it is the open price of every share price
# name_c:- it is the close price of every share price
#
# qty=20000/share price of 1st-0ct-2020

# %%
#Creating names of columns
name_qty=[]

for n in list_of_companies:
    name_qty.append(n+'_qty')
    
    
#creating a dataset with qtantity columns
j=0
for col in name_o:
    data[name_qty[j]]=20000/data[col][0]
    j+=1

# %% [markdown]
# #Daily Value = close price * qty

# %%
#Creating names of columns
name_DV=[]

for n in list_of_companies:
    name_DV.append(n+'_DV')
    
#creating a column with daily values of share price  
j=0
for j in range(0,50):
    for i in range(0,515):
        data[name_DV[j]]=range(0,515)#To create a blanck cells for assingment.


j=0
for qty in name_qty:
    for i in range(0,515):
        data[name_DV[j]][i]=data[qty][0]*data[name_c[j]][i]
    j+=1

# %%
data
# Out:
#            Date     MARUTI_o     MARUTI_c   RELIANCE_o   RELIANCE_c  \
# 0    2020-10-01  6838.200195  6796.299805  2263.800049  2225.250000
# 1    2020-10-05  6865.000000  6818.850098  2244.000000  2212.199951
# 2    2020-10-06  6858.000000  6892.399902  2225.250000  2210.350098
# 3    2020-10-07  6920.000000  7046.899902  2235.000000  2257.500000
# 4    2020-10-08  7090.000000  7079.850098  2259.000000  2239.250000
# ..          ...          ...          ...          ...          ...
# 510  2022-10-21  8730.000000  8703.299805  2507.699951  2471.600098
# 511  2022-10-24  8788.799805  8765.450195  2460.000000  2479.850098
# 512  2022-10-25  8820.000000  9005.000000  2499.000000  2441.550049
# 513  2022-10-27  9050.000000  9041.950195  2458.000000  2451.149902
# 514  2022-10-28  9095.000000  9492.549805  2465.000000  2526.149902
#
#      APOLLOHOSP_o  APOLLOHOSP_c      NTPC_o      NTPC_c  HEROMOTOCO_o  ...  \
# ...

# %%
#calculating the daily value of portfolio.
j=0
for i in range(0,515):
        data['Total_Equity']=range(0,515)#To create a black cells for assingment.
for i in range(0,515):
    sum=0
    for j in name_DV:
        sum=sum+data[j][i]
    sum=round(sum,3)
    data['Total_Equity'][i]=sum

# %%
data
# Out:
#            Date     MARUTI_o     MARUTI_c   RELIANCE_o   RELIANCE_c  \
# 0    2020-10-01  6838.200195  6796.299805  2263.800049  2225.250000
# 1    2020-10-05  6865.000000  6818.850098  2244.000000  2212.199951
# 2    2020-10-06  6858.000000  6892.399902  2225.250000  2210.350098
# 3    2020-10-07  6920.000000  7046.899902  2235.000000  2257.500000
# 4    2020-10-08  7090.000000  7079.850098  2259.000000  2239.250000
# ..          ...          ...          ...          ...          ...
# 510  2022-10-21  8730.000000  8703.299805  2507.699951  2471.600098
# 511  2022-10-24  8788.799805  8765.450195  2460.000000  2479.850098
# 512  2022-10-25  8820.000000  9005.000000  2499.000000  2441.550049
# 513  2022-10-27  9050.000000  9041.950195  2458.000000  2451.149902
# 514  2022-10-28  9095.000000  9492.549805  2465.000000  2526.149902
#
#      APOLLOHOSP_o  APOLLOHOSP_c      NTPC_o      NTPC_c  HEROMOTOCO_o  ...  \
# ...

# %% [markdown]
# # Benchmark Strategy
# 1. Equity curve

# %%
data['Total_Equity']
# Out:
# 0      1005039.229
# 1      1012822.149
# 2      1021032.640
# 3      1022173.521
# 4      1027884.546
#           ...
# 510    1897905.002
# 511    1911771.006
# 512    1909598.428
# 513    1924036.062
# 514    1924709.093
# Name: Total_Equity, Length: 515, dtype: float64

# %%
sn.lineplot(data['Total_Equity'], color='black')
# Out:
# <AxesSubplot:ylabel='Total_Equity'>

# %% [markdown]
# # Sample Strategy

# %% [markdown]
# 2. (Sample Strategy) Past Returns based Selection:
# Instead of investing in all the 50 stocks, let us select a few based on their performance in the past.
#
# I. Take the prices till one day prior to investment day (Simulation Start Date)
#
# II. Measure the performance of the latest 100 days, in terms of percentage returns
# (Close (last day) / Close (100th day before last day) - 1)
#
# III. Select the top 10 best performing stocks (i.e., the ones that have the best returns)
#
# Invest the Initial Investment equally among the 10 stocks during the beginning of the simulation and
# hold it till the end and get the portfolio equity curve.

# %%
df_2=pd.read_csv("D:\\data set\\niffty\\MARUTI.NS.csv")
df1_2=pd.read_csv("D:\\data set\\niffty\\RELIANCE.NS.csv")
df2_2=pd.read_csv("D:\\data set\\niffty\\APOLLOHOSP.NS.csv")
df3_2=pd.read_csv("D:\\data set\\niffty\\NTPC.NS.csv")
df4_2=pd.read_csv("D:\\data set\\niffty\\HEROMOTOCO.NS.csv")
df5_2=pd.read_csv("D:\\data set\\niffty\\POWERGRID.NS.csv")
df6_2=pd.read_csv("D:\\data set\\niffty\\M&M.NS.csv")
df7_2=pd.read_csv("D:\\data set\\niffty\\ONGC.NS.csv")
df8_2=pd.read_csv("D:\\data set\\niffty\\COALINDIA.NS.csv")
df9_2=pd.read_csv("D:\\data set\\niffty\\BAJAJ-AUTO.NS.csv")
df10_2=pd.read_csv("D:\\data set\\niffty\\BAJAJFINSV.NS.csv")

df11_2=pd.read_csv("D:\\data set\\niffty\\KOTAKBANK.NS.csv")
df12_2=pd.read_csv("D:\\data set\\niffty\\TITAN.NS.csv")
df13_2=pd.read_csv("D:\\data set\\niffty\\EICHERMOT.NS.csv")
df14_2=pd.read_csv("D:\\data set\\niffty\\UPL.NS.csv")
df15_2=pd.read_csv("D:\\data set\\niffty\\HDFCLIFE.NS.csv")
df16_2=pd.read_csv("D:\\data set\\niffty\\NESTLEIND.NS.csv")
df17_2=pd.read_csv("D:\\data set\\niffty\\LT.NS.csv")
df18_2=pd.read_csv("D:\\data set\\niffty\\TATAMOTORs.NS.csv")
df19_2=pd.read_csv("D:\\data set\\niffty\\BRITANNIA.NS.csv")
df20_2=pd.read_csv("D:\\data set\\niffty\\BAJAJFINSV.NS.csv")

df21_2=pd.read_csv("D:\\data set\\niffty\\HDFCBANK.NS.csv")
df22_2=pd.read_csv("D:\\data set\\niffty\\INDUSINDBK.NS.csv")
df23_2=pd.read_csv("D:\\data set\\niffty\\ASIANPAINT.NS.csv")
df24_2=pd.read_csv("D:\\data set\\niffty\\HINDUNILVR.NS.csv")
df25_2=pd.read_csv("D:\\data set\\niffty\\BHARTIARTL.NS.csv")
df26_2=pd.read_csv("D:\\data set\\niffty\\WIPRO.NS.csv")
df27_2=pd.read_csv("D:\\data set\\niffty\\TCS.NS.csv")
df28_2=pd.read_csv("D:\\data set\\niffty\\UlTRACEMCO.NS.csv")
df29_2=pd.read_csv("D:\\data set\\niffty\\ITC.NS.csv")
df30_2=pd.read_csv("D:\\data set\\niffty\\ADANIENT.NS.csv")

df31_2=pd.read_csv("D:\\data set\\niffty\\SBILIFE.NS.csv")
df32_2=pd.read_csv("D:\\data set\\niffty\\HCLTECH.NS.csv")
df33_2=pd.read_csv("D:\\data set\\niffty\\ADANIPORTS.NS.csv")
df34_2=pd.read_csv("D:\\data set\\niffty\\HDFCLIFE.NS.csv")
df35_2=pd.read_csv("D:\\data set\\niffty\\BPCL.NS.csv")
df36_2=pd.read_csv("D:\\data set\\niffty\\INFY.NS.csv")
df37_2=pd.read_csv("D:\\data set\\niffty\\CIPLA.NS.csv")
df38_2=pd.read_csv("D:\\data set\\niffty\\DRREDDY.NS.csv")
df39_2=pd.read_csv("D:\\data set\\niffty\\TATACONSUM.NS.csv")
df40_2=pd.read_csv("D:\\data set\\niffty\\AXISBANK.NS.csv")

df41_2=pd.read_csv("D:\\data set\\niffty\\SBIN.NS.csv")
df42_2=pd.read_csv("D:\\data set\\niffty\\JSWSTEEL.NS.csv")
df43_2=pd.read_csv("D:\\data set\\niffty\\ICICIBANK.NS.csv")
df44_2=pd.read_csv("D:\\data set\\niffty\\HINDALCO.NS.csv")
df45_2=pd.read_csv("D:\\data set\\niffty\\DIVISLAB.NS.csv")
df46_2=pd.read_csv("D:\\data set\\niffty\\GRASIM.NS.csv")
df47_2=pd.read_csv("D:\\data set\\niffty\\SUNPHARMA.NS.csv")
df48_2=pd.read_csv("D:\\data set\\niffty\\TATASTEEL.NS.csv")
df49_2=pd.read_csv("D:\\data set\\niffty\\TECHM.NS.csv")

# %%
dataframelist_2=[df_2,df1_2,df2_2,df3_2,df4_2,df5_2,df6_2,df7_2,df8_2,df9_2,df10_2,df11_2,df12_2,df13_2,df14_2,df15_2,df16_2
               ,df17_2,df18_2,df19_2,df20_2,df21_2,df22_2,df23_2,df24_2,df25_2,df26_2,df27_2,df28_2,df29_2,df30_2,df31_2,df32_2,df33_2
               ,df34_2,df35_2,df36_2,df37_2,df38_2,df39_2,df40_2,df41_2,df42_2,df43_2,df44_2,df45_2,df46_2,df47_2,df48_2,df49_2]

# %%
#datachecking checking
for i in dataframelist_2:
    print(i.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       100 non-null    object
#  1   Open       100 non-null    float64
#  2   High       100 non-null    float64
#  3   Low        100 non-null    float64
#  4   Close      100 non-null    float64
#  5   Adj Close  100 non-null    float64
#  6   Volume     100 non-null    int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 5.6+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       100 non-null    object
#  1   Open       100 non-null    float64
#  2   High       100 non-null    float64
#  3   Low        100 non-null    float64
#  4   Close      100 non-null    float64
#  5   Adj Close  100 non-null    float64
# ...

# %%
#Data base Creation
data_2=pd.DataFrame()
data_2['Date']=df_2['Date']


#Creating names of columns
name_o_2=[]
name_c_2=[]
for n in list_of_companies:
    name_o_2.append(n+'_o')
    name_c_2.append(n+'_c')


#creating a dataset with open and close values only
i=0
for col in dataframelist_2:
    data_2[name_o_2[i]]=col['Open']
    data_2[name_c_2[i]]=col['Close']
    i+=1

# %%
data_2
# Out:
#           Date     MARUTI_o     MARUTI_c   RELIANCE_o   RELIANCE_c  \
# 0   2020-06-12  5201.000000  5561.750000  1500.000000  1588.800049
# 1   2020-06-15  5520.000000  5475.750000  1565.000000  1614.550049
# 2   2020-06-16  5590.000000  5502.200195  1643.000000  1617.699951
# 3   2020-06-17  5445.000000  5726.200195  1608.250000  1615.349976
# 4   2020-06-18  5695.000000  5714.399902  1607.000000  1655.900024
# ..         ...          ...          ...          ...          ...
# 95  2020-10-26  7100.000000  7054.799805  2101.949951  2029.099976
# 96  2020-10-27  7067.000000  7158.399902  2034.900024  2034.500000
# 97  2020-10-28  7194.950195  7186.049805  2041.800049  2011.449951
# 98  2020-10-29  7114.000000  7117.700195  1997.000000  2026.900024
# 99  2020-10-30  7079.049805  6965.149902  2033.500000  2054.500000
#
#     APOLLOHOSP_o  APOLLOHOSP_c     NTPC_o     NTPC_c  HEROMOTOCO_o  ...  \
# 0    1305.000000   1403.599976  94.500000  96.900002   2242.000000  ...
# ...

# %%
#Creating a New dataframe with company names and returns of company
#defining dataset and creating the columns
df_roe=pd.DataFrame()
df_roe['Name_of_companies']=range(0,50)
df_roe['percentage_returns']=range(0,50)
for i in range(0,50):
    df_roe['Name_of_companies'][i]=list_of_companies[i]



#calculating Roi    
i=0    
for col in name_c_2:
    roi=0
    roi=((data_2[name_c_2[i]][99]/data_2[name_c_2[i]][0])-1)
    df_roe['percentage_returns'][i]=roi
    i+=1

# %%
df_roe
# Out:
#    Name_of_companies  percentage_returns
# 0             MARUTI            0.252331
# 1           RELIANCE            0.293114
# 2         APOLLOHOSP            0.510010
# 3               NTPC           -0.095975
# 4         HEROMOTOCO            0.165685
# 5          POWERGRID            0.028262
# 6                M&M            0.168256
# 7               ONGC           -0.226460
# 8          COALINDIA           -0.151875
# 9         BAJAJ-AUTO            0.037651
# 10        BAJAJFINSV            0.054399
# 11         KOTAKBANK            0.209095
# 12             TITAN            0.192339
# 13         EICHERMOT            0.237209
# 14               UPL            0.101057
# 15              HDFC            0.174099
# 16         NESTLEIND            0.040330
# 17                LT            0.003346
# 18        TATAMOTORs            0.259734
# 19         BRITANNIA            0.031847
# 20        BAJFINANCE            0.054399
# 21          HDFCBANK            0.204325
# ...

# %% [markdown]
# #AFTER DOING 100 days of data valuation these are the top 10 companies with highest return in the list of niffty 50 coampanies

# %%
df_roe=df_roe.sort_values(by='percentage_returns',ascending=False)
df_roe.head(10)
# Out:
#    Name_of_companies  percentage_returns
# 30          ADANIENT            1.230466
# 26             WIPRO            0.638769
# 42          JSWSTEEL            0.635353
# 36              INFY            0.532548
# 2         APOLLOHOSP            0.510010
# 32           HCLTECH            0.475164
# 49             TECHM            0.466198
# 23        ASIANPAINT            0.350658
# 39        TATACONSUM            0.328437
# 45          DIVISLAB            0.311866

# %%
#Again Creating a list with top 10 companies with highest return

companies_top_10=['ADANIENT','WIPRO','JSWSTEEL','INFY','APOLLOHOSP','HCLTECH'
                  ,'TECHM','ASIANPAINT','TATACONSUM','DIVISLAB',]

# %%
df30_2=pd.read_csv("D:\\data set\\niffty50\\ADANIENT.NS.csv")
df26_2=pd.read_csv("D:\\data set\\niffty50\\WIPRO.NS.csv")
df42_2=pd.read_csv("D:\\data set\\niffty50\\JSWSTEEL.NS.csv")
df36_2=pd.read_csv("D:\\data set\\niffty50\\INFY.NS.csv")
df2_2=pd.read_csv("D:\\data set\\niffty50\\APOLLOHOSP.NS.csv")
df32_2=pd.read_csv("D:\\data set\\niffty50\\HCLTECH.NS.csv")
df49_2=pd.read_csv("D:\\data set\\niffty50\\TECHM.NS.csv")
df23_2=pd.read_csv("D:\\data set\\niffty50\\ASIANPAINT.NS.csv")
df39_2=pd.read_csv("D:\\data set\\niffty50\\TATACONSUM.NS.csv")
df45_2=pd.read_csv("D:\\data set\\niffty50\\DIVISLAB.NS.csv")

dataframelist_2=[df30_2,df26_2,df42_2,df36_2,df36_2,df2_2,df32_2,df49_2,df23_2,df39_2]

# %%
#Data base Creation
data_2=pd.DataFrame()
data_2['Date']=df30_2['Date']


#Creating names of columns
name_o_2=[]
name_c_2=[]
for n in companies_top_10:
    name_o_2.append(n+'_o')
    name_c_2.append(n+'_c')


#creating a dataset with open and close values only
i=0
for col in dataframelist_2:
    data_2[name_o_2[i]]=col['Open']
    data_2[name_c_2[i]]=col['Close']
    i+=1

# %%
data_2
# Out:
#            Date   ADANIENT_o   ADANIENT_c     WIPRO_o     WIPRO_c  JSWSTEEL_o  \
# 0    2020-10-01   299.799988   308.149994  316.399994  313.049988  281.450012
# 1    2020-10-05   311.500000   326.600006  315.200012  333.950012  284.299988
# 2    2020-10-06   329.399994   327.149994  335.000000  330.049988  292.750000
# 3    2020-10-07   325.149994   330.100006  327.000000  335.299988  290.000000
# 4    2020-10-08   329.000000   316.250000  351.000000  359.450012  291.500000
# ..          ...          ...          ...         ...         ...         ...
# 510  2022-10-21  3374.899902  3311.899902  382.500000  382.549988  630.099976
# 511  2022-10-24  3325.000000  3309.800049  386.399994  384.700012  622.000000
# 512  2022-10-25  3321.949951  3300.500000  386.450012  384.649994  624.200012
# 513  2022-10-27  3319.850098  3325.000000  386.000000  382.649994  650.000000
# 514  2022-10-28  3322.000000  3323.300049  382.799988  383.250000  676.599976
#
# ...

# %% [markdown]
# #Now Buying the share(Creating the quantity (1000000/10=100000)100000 assigned for every company)
#
# name_o:- it is the open price of every share price
# name_c:- it is the close price of every share price
#
# qty=100000/share price of 1st-0ct-2020

# %%
#Creating names of columns
name_qty_2=[]

for n in companies_top_10:
    name_qty_2.append(n+'_qty')
    
    
#creating a dataset with qtantity columns
j=0
for col in name_o_2:
    data_2[name_qty_2[j]]=100000/data_2[col][0]
    j+=1

# %%
#Creating names of columns
name_DV_2=[]

for n in companies_top_10:
    name_DV_2.append(n+'_DV')
    
#creating a column with daily values of share price  
j=0
for j in range(0,10):
    for i in range(0,515):
        data_2[name_DV_2[j]]=range(0,515)#To create a blanck cells for assingment.


j=0
for qty in name_qty_2:
    for i in range(0,515):
        sum=data_2[qty][0]*data_2[name_c_2[j]][i]
        data_2[name_DV_2[j]][i]=round(sum,3)
    j+=1

# %%
data_2
# Out:
#            Date   ADANIENT_o   ADANIENT_c     WIPRO_o     WIPRO_c  JSWSTEEL_o  \
# 0    2020-10-01   299.799988   308.149994  316.399994  313.049988  281.450012
# 1    2020-10-05   311.500000   326.600006  315.200012  333.950012  284.299988
# 2    2020-10-06   329.399994   327.149994  335.000000  330.049988  292.750000
# 3    2020-10-07   325.149994   330.100006  327.000000  335.299988  290.000000
# 4    2020-10-08   329.000000   316.250000  351.000000  359.450012  291.500000
# ..          ...          ...          ...         ...         ...         ...
# 510  2022-10-21  3374.899902  3311.899902  382.500000  382.549988  630.099976
# 511  2022-10-24  3325.000000  3309.800049  386.399994  384.700012  622.000000
# 512  2022-10-25  3321.949951  3300.500000  386.450012  384.649994  624.200012
# 513  2022-10-27  3319.850098  3325.000000  386.000000  382.649994  650.000000
# 514  2022-10-28  3322.000000  3323.300049  382.799988  383.250000  676.599976
#
# ...

# %%
#calculating the daily value of portfolio.
j=0
for i in range(0,515):
        data_2['Total_Equity']=range(0,515)#To create a black cells for assingment.
for i in range(0,515):
    sum=0
    for j in name_DV_2:
        sum=sum+data_2[j][i]
    sum=round(sum,3)
    data_2['Total_Equity'][i]=sum

# %%
data_2
# Out:
#            Date   ADANIENT_o   ADANIENT_c     WIPRO_o     WIPRO_c  JSWSTEEL_o  \
# 0    2020-10-01   299.799988   308.149994  316.399994  313.049988  281.450012
# 1    2020-10-05   311.500000   326.600006  315.200012  333.950012  284.299988
# 2    2020-10-06   329.399994   327.149994  335.000000  330.049988  292.750000
# 3    2020-10-07   325.149994   330.100006  327.000000  335.299988  290.000000
# 4    2020-10-08   329.000000   316.250000  351.000000  359.450012  291.500000
# ..          ...          ...          ...         ...         ...         ...
# 510  2022-10-21  3374.899902  3311.899902  382.500000  382.549988  630.099976
# 511  2022-10-24  3325.000000  3309.800049  386.399994  384.700012  622.000000
# 512  2022-10-25  3321.949951  3300.500000  386.450012  384.649994  624.200012
# 513  2022-10-27  3319.850098  3325.000000  386.000000  382.649994  650.000000
# 514  2022-10-28  3322.000000  3323.300049  382.799988  383.250000  676.599976
#
# ...

# %%
sn.lineplot(data_2['Total_Equity'], color='black')
# Out:
# <AxesSubplot:ylabel='Total_Equity'>

# %% [markdown]
# # 3. Niffty  INDEX CURVE

# %%
df_Niffty=pd.read_csv("D:\\data set\\niffty50\\NSEI.csv")

# %%
niffty=pd.DataFrame()
niffty['Niffty_o']=df_Niffty['Open']
niffty['Niffty_c']=df_Niffty['Close']

# %%
niffty['niffty_qty']=1000000/niffty['Niffty_o'][0]

# %%
niffty['niffty_dv_value']=range(0,515)
for i in range(0,515):
    sum=niffty['niffty_qty'][0]*niffty['Niffty_c'][i]
    niffty['niffty_dv_value'][i]=round(sum,3)

# %%
niffty
# Out:
#          Niffty_o      Niffty_c  niffty_qty  niffty_dv_value
# 0    11364.450195  11416.950195   87.993698      1004619.669
# 1    11487.799805  11503.349609   87.993698      1012222.273
# 2    11603.450195  11662.400391   87.993698      1026217.740
# 3    11679.250000  11738.849609   87.993698      1032944.789
# 4    11835.400391  11834.599609   87.993698      1041370.186
# ..            ...           ...         ...              ...
# 510  17622.849609  17576.300781   87.993698      1546603.705
# 511  17736.349609  17730.750000   87.993698      1560194.263
# 512  17808.300781  17656.349609   87.993698      1553647.498
# 513  17771.400391  17736.949219   87.993698      1560739.756
# 514  17756.400391  17786.800781   87.993698      1565126.379
#
# [515 rows x 4 columns]

# %%
sn.lineplot(niffty['niffty_dv_value'], color='black')
# Out:
# <AxesSubplot:ylabel='niffty_dv_value'>

# %% [markdown]
# # 4. summarizing the performance

# %% [markdown]
# # 1.  Equal alloc buy hold

# %%
#for  Equal alloc buy hold
#a
cagr=list(range(0,3))
cagr[0]=((((data['Total_Equity'][514]/1000000)**(1/2))-1)*100)

#performance_strat
#b
cagr[1]=((((data_2['Total_Equity'][514]/1000000)**(1/2))-1)*100)

#niffty
#c
cagr[2]=((((niffty['niffty_dv_value'][514]/1000000)**(1/2))-1)*100)


cagr
# Out:
# [38.733885298437464, 59.23495819071891, 25.105011050716918]

# %% [markdown]
# # 2.volatility

# %%
import statistics as st

# %%
#for  Equal alloc buy hold

#Creating names of columns
name_DR=[]

for n in list_of_companies:
    name_DR.append(n+'_DR')
j=0
for qty in name_DV:
    data[name_DR[j]] = data[qty].pct_change(1)
    j+=1

    
    
#calculating the daily value of portfolio.
j=0
for i in range(0,515):
        data['total_DR']=range(0,515)#To create a black cells for assingment.

#Adding the value of daily return of 50 companies        
for i in range(0,515):
    sum=0
    for j in name_DR:
        sum=sum+data[j][i]
    sum=round(sum,3)
    data['total_DR'][i]=sum   

    
    
#now calculating the Standard deviation of DAily return
s1=data['total_DR'].std()

# %%
data
# Out:
#            Date     MARUTI_o     MARUTI_c   RELIANCE_o   RELIANCE_c  \
# 0    2020-10-01  6838.200195  6796.299805  2263.800049  2225.250000
# 1    2020-10-05  6865.000000  6818.850098  2244.000000  2212.199951
# 2    2020-10-06  6858.000000  6892.399902  2225.250000  2210.350098
# 3    2020-10-07  6920.000000  7046.899902  2235.000000  2257.500000
# 4    2020-10-08  7090.000000  7079.850098  2259.000000  2239.250000
# ..          ...          ...          ...          ...          ...
# 510  2022-10-21  8730.000000  8703.299805  2507.699951  2471.600098
# 511  2022-10-24  8788.799805  8765.450195  2460.000000  2479.850098
# 512  2022-10-25  8820.000000  9005.000000  2499.000000  2441.550049
# 513  2022-10-27  9050.000000  9041.950195  2458.000000  2451.149902
# 514  2022-10-28  9095.000000  9492.549805  2465.000000  2526.149902
#
#      APOLLOHOSP_o  APOLLOHOSP_c      NTPC_o      NTPC_c  HEROMOTOCO_o  ...  \
# ...

# %%
#performance_strat

#Creating names of columns
name_DR=[]

for n in companies_top_10:
    name_DR.append(n+'_DR')
j=0
for qty in name_DV_2:
    data_2[name_DR[j]] = data_2[qty].pct_change(1)
    j+=1

    
    
#calculating the daily value of portfolio.
j=0
for i in range(0,515):
        data_2['total_DR']=range(0,515)#To create a black cells for assingment.
        
        
        

#Adding the value of daily return of 10 companies
for i in range(0,515):
    sum=0
    for j in name_DR:
        sum=sum+data_2[j][i]
    sum=round(sum,3)
    data_2['total_DR'][i]=sum   

    
    
#now calculating the Standard deviation of DAily return
s2=data_2['total_DR'].std()

# %%
data_2
# Out:
#            Date   ADANIENT_o   ADANIENT_c     WIPRO_o     WIPRO_c  JSWSTEEL_o  \
# 0    2020-10-01   299.799988   308.149994  316.399994  313.049988  281.450012
# 1    2020-10-05   311.500000   326.600006  315.200012  333.950012  284.299988
# 2    2020-10-06   329.399994   327.149994  335.000000  330.049988  292.750000
# 3    2020-10-07   325.149994   330.100006  327.000000  335.299988  290.000000
# 4    2020-10-08   329.000000   316.250000  351.000000  359.450012  291.500000
# ..          ...          ...          ...         ...         ...         ...
# 510  2022-10-21  3374.899902  3311.899902  382.500000  382.549988  630.099976
# 511  2022-10-24  3325.000000  3309.800049  386.399994  384.700012  622.000000
# 512  2022-10-25  3321.949951  3300.500000  386.450012  384.649994  624.200012
# 513  2022-10-27  3319.850098  3325.000000  386.000000  382.649994  650.000000
# 514  2022-10-28  3322.000000  3323.300049  382.799988  383.250000  676.599976
#
# ...

# %%
data_2['total_DR'].sum()
# Out:
# 7.2989999999999995

# %%
#niffty


niffty['total_DR'] = niffty['Niffty_c'].pct_change(1)
s3=niffty['total_DR'].std()

# %%
volatility=list(range(0,3))

volatility[0]=((s1)**(1/252))*100
volatility[1]=((s2)**(1/252))*100
volatility[2]=((s3)**(1/252))*100

# %% [markdown]
# # volatility

# %% [markdown]
# # 3. sharpe ratio

# %%
#for  Equal alloc buy hold
m1=data['total_DR'].mean()
m2=data_2['total_DR'].mean()
m3=niffty['total_DR'].mean()

m1,m2,m3
# Out:
# (0.06050389105058364, 0.014200389105058386, 0.0009183301160038493)

# %%
Shapre=list(range(0,3))

Shapre[0]=(data['total_DR'].mean()/data['total_DR'].std())**(1/252)
Shapre[1]=(data_2['total_DR'].mean()/data_2['total_DR'].std())**(1/252)
Shapre[2]=(niffty['total_DR'].mean()/niffty['total_DR'].std())**(1/252)
Shapre
# Out:
# [0.9914904094374323, 0.9913968307875105, 0.9903685338535226]

# %% [markdown]
# # results

# %%
sn.lineplot(y=data['Total_Equity'],x=data['Date'], color='purple',label='Equal alloc buy hold')
sn.lineplot(y=data_2['Total_Equity'],x=data['Date'] ,color='Green',label='performance_strat')
sn.lineplot(y=niffty['niffty_dv_value'],x=data['Date'], color='red',label='niffty')

plt.legend()
plt.show()

# %%
pf = pd.DataFrame()
pf['INDEX']=['Equal alloc buy hold','performance_strat','niffty']
pf['Cagr %']=cagr
pf['volatility %']=volatility
pf['Shapre']=Shapre

# %%
pf
# Out:
#                   INDEX     Cagr %  volatility %    Shapre
# 0  Equal alloc buy hold  38.733885     99.741820  0.991490
# 1     performance_strat  59.234958     99.179139  0.991397
# 2                niffty  25.105011     98.209065  0.990369
